# %%
print("helllo world")
# Out:
# helllo world

# %%
import sys
# !{sys.executable} -m pip install pillow qwen-vl-utils
# Out:
# Requirement already satisfied: pillow in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (12.0.0)
# Collecting qwen-vl-utils
#   Using cached qwen_vl_utils-0.0.14-py3-none-any.whl.metadata (9.0 kB)
# Collecting av (from qwen-vl-utils)
#   Downloading av-16.1.0-cp312-cp312-macosx_11_0_x86_64.whl.metadata (4.6 kB)
# Requirement already satisfied: packaging in /Users/imac/Library/Python/3.12/lib/python/site-packages (from qwen-vl-utils) (25.0)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from qwen-vl-utils) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->qwen-vl-utils) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->qwen-vl-utils) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->qwen-vl-utils) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->qwen-vl-utils) (2025.11.12)
# Using cached qwen_vl_utils-0.0.14-py3-none-any.whl (8.1 kB)
# Downloading av-16.1.0-cp312-cp312-macosx_11_0_x86_64.whl (26.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.9/26.9 MB 4.4 MB/s  0:00:06m0:00:0100:01
# Installing collected packages: av, qwen-vl-utils
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [qwen-vl-utils]0m [qwen-vl-utils]
# Successfully installed av-16.1.0 qwen-vl-utils-0.0.14

# %%
import torch
from PIL import Image
from transformers import Qwen2VLForConditionalGeneration, Qwen2VLProcessor
from qwen_vl_utils import process_vision_info

# %%
model_id = "Qwen/Qwen2-VL-7B-Instruct"
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")
# Out:
# Using device: cpu
