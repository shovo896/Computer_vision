# %%
! pip install PTL
# Out:
# ...
#   Using cached ptl-0.3.0-py3-none-any.whl.metadata (12 kB)
# Using cached ptl-0.3.0-py3-none-any.whl (22 kB)
# ...

# %%
from PTL import Image
import requests
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-1955492457.py in <cell line: 0>()
# ----> 1 from PTL import Image
#       2 import requests
#
# ModuleNotFoundError: No module named 'PTL'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
