# %%
import numpy as np
import cv2 as cv
from pathlib import Path
import matplotlib.pyplot as plt

img_path = Path('hndxjb.avif').resolve()
img = cv.imread(str(img_path))
if img is None:
    raise FileNotFoundError(f'Could not read image at {img_path}')

rows, cols = img.shape[:2]
M = np.float32([[1, 0, 100], [0, 1, 50]])
dst = cv.warpAffine(img, M, (cols, rows))

# Display in notebook
img_rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)
dst_rgb = cv.cvtColor(dst, cv.COLOR_BGR2RGB)

fig, axes = plt.subplots(1, 2, figsize=(8, 4))
axes[0].imshow(img_rgb)
axes[0].set_title('Input')
axes[0].axis('off')
axes[1].imshow(dst_rgb)
axes[1].set_title('Output')
axes[1].axis('off')
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 9
#       7 img = cv.imread(str(img_path))
#       8 if img is None:
# ----> 9     raise FileNotFoundError(f'Could not read image at {img_path}')
#      11 rows, cols = img.shape[:2]
#      12 M = np.float32([[1, 0, 100], [0, 1, 50]])
#
# FileNotFoundError: Could not read image at /Users/imac/Computer_vision/hndxjb.avif
