# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import os
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from skmultilearn.adapt import MLkNN
from sklearn.metrics import accuracy_score, classification_report, hamming_loss
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 6
#       4 import os
#       5 from sklearn.model_selection import train_test_split
# ----> 6 from sklearn.feature_extraction import TfidfVectorizer
#       7 from sklearn.linear_model import LogisticRegression
#       8 from skmultilearn.adapt import MLkNN
#
# ImportError: cannot import name 'TfidfVectorizer' from 'sklearn.feature_extraction' (/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/feature_extraction/__init__.py)
